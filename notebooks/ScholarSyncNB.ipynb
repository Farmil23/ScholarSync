# %%
import os
from typing import Any, List, Optional
from langchain_core.language_models.llms import LLM
from langchain_core.callbacks.manager import CallbackManagerForLLMRun
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever, ContextualCompressionRetriever
from langchain_classic.retrievers.document_compressors import CrossEncoderReranker
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from langchain_classic.chains import RetrievalQA
from langchain_classic.schema import Document
from byteplussdkarkruntime import Ark
from dotenv import load_dotenv
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai import OpenAIEmbeddings
from langchain_astradb import AstraDBVectorStore

# %%
# ==========================================
# 1. WRAPPER BYTEPLUS
# ==========================================
load_dotenv()
api_key = os.getenv("ARK_API_KEY")
endpoint_id = os.getenv("MODEL_ENDPOINT_ID")

class BytePlusLLM(LLM):
    api_key: str
    endpoint_id: str
    client: Any = None

    def __init__(self, api_key, endpoint_id):
        super().__init__(api_key=api_key, endpoint_id=endpoint_id)
        self.client = Ark(
            api_key=api_key,
            base_url="https://ark.ap-southeast.bytepluses.com/api/v3"
        )

    @property
    def _llm_type(self) -> str:
        return "byteplus_ark"

    def _call(self, prompt: str, stop: Optional[List[str]] = None, **kwargs: Any) -> str:
        try:
            completion = self.client.chat.completions.create(
                model=self.endpoint_id,
                messages=[
                    {"role": "system", "content": "Jawab dengan singkat dan jelas berdasarkan konteks."},
                    {"role": "user", "content": prompt}
                ]
            )
            return completion.choices[0].message.content
        except Exception as e:
            return f"Error API: {e}"

# %%
open_ai_api_key = os.getenv("OPENAI_API_KEY")

# %%
def smartChunkProcessor(file_path, chunk_size=1000, chunk_overlap=200) -> List[Document]:
    """
    Split text into chunks with overlap for better context retention.
    """
    docs = PyMuPDFLoader(file_path)
    document = docs.load()

    ## text Splitter
    embeddings = OpenAIEmbeddings(api_key = open_ai_api_key, model="text-embedding-3-small")

    text_splitter = SemanticChunker(
        embeddings=embeddings,
        breakpoint_threshold_amount=0.9, # Example value
        min_chunk_size=100
    )

    chunks = text_splitter.split_documents(document)
    return chunks

# %%
chunks = smartChunkProcessor("../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf")

# %%
chunks
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Journal of Computer System and Informatics (JoSYC)  \nISSN 2714-8912 (media online), ISSN 2714-7150 (media cetak) \nVolume 6, No. 1, November 2024, Page 293-304 \nhttps://ejurnal.seminar-id.com/index.php/josyc \nDOI 10.47065/josyc.v6i1.6182 \n \nCopyright © 2024 Author, Page 293  \nThis Journal is licensed under a Creative Commons Attribution 4.0 International License \n Aplikasi Web Question Answering Menggunakan Langchain OpenAI \nTentang Peraturan Perundang-Undangan Bidang Pendidikan \nIkhsan Dwi Saputra, Nazruddin Safaat Harahap*, Surya Agustian, Muhammad Fikry, Lola Oktavia \nFakultas Sains Dan Teknologi, Teknik Informatika, Universitas Islam Negeri Sultan Syarif Kasim Riau, Pekanbaru, \nIndonesia \nEmail: 112050113500@students.uin-suska.ac.id, 2,*nazruddin.safaat@uin-suska.ac.id, 3surya.agustian@uin-suska.ac.id, \n4muhammad.fikry@uin-suska.ac.id, 5lola.oktavia@uin-suska.ac.id \nEmail Penulis Korespondensi: nazruddin.safaat@uin-suska.ac.id \nSubmitted: 01/11/2024; Accepted: 30/11/2024; Published: 30/11/2024 \nAbstrak−Dalam perkembangan teknologi informasi yang pesat selama beberapa tahun terakhir, kemudahan dalam \nmengakses informasi telah menjadi salah satu pencapaian yang signifikan.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Kecerdasan buatan (AI) telah muncul sebagai alat \nyang potensial dalam menghadirkan solusi inovatif di berbagai sektor kehidupan manusia.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Penelitian ini bertujuan untuk \nmengembangkan sebuah aplikasi web yang mampu menjawab pertanyaan terkait peraturan perundang-undangan di bidang \npendidikan dengan memanfaatkan framework LangChain dan model BERT.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Masalah utama yang dihadapi adalah \nkompleksitas dan volume dokumen legal yang sulit diakses dan dipahami oleh pengguna awam.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Metode yang digunakan \ndalam penelitian ini melibatkan konversi dokumen legal dari format PDF ke teks, pemotongan teks menggunakan \nLangChain, dan evaluasi performa sistem menggunakan BERTScore dan ROUGE Score.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Hasil penelitian menunjukkan \nbahwa BERTScore lebih unggul dalam mengukur kesesuaian antara jawaban sistem dan referensi, dengan beberapa \npertanyaan mendapatkan skor 100%.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Namun, terdapat beberapa keterbatasan seperti proses konversi dokumen yang \nmemerlukan upaya manual dan kebutuhan sumber daya komputasi yang besar untuk pemrosesan teks.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Penelitian ini \nmemberikan kontribusi signifikan dalam memfasilitasi akses dan pemahaman dokumen legal pendidikan, serta membuka \npeluang untuk pengembangan lebih lanjut dengan teknik konversi dan model AI yang lebih canggih.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Kata Kunci: Question Answering; LangChain; BERTScore; ROUGE Score; Dokumen Legal; Pendidikan \nAbstract−In the rapid development of information technology over the past few years, the ease of accessing information has \nbeen one of the significant achievements.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Artificial intelligence (AI) has emerged as a potential tool in bringing innovative \nsolutions in various sectors of human life.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='This research aims to develop a web application capable of answering questions \nrelated to educational legislation using the LangChain framework and BERT model.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='The primary issue addressed is the \ncomplexity and volume of legal documents that are challenging for lay users to access and understand.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='The methodology \ninvolves converting legal documents from PDF to text, segmenting the text using LangChain, and evaluating system \nperformance with BERTScore and ROUGE Score.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='The results indicate that BERTScore is superior in measuring the \nalignment between the system’s answers and reference answers, with some questions achieving a score of 100%.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='However, \nthere are limitations, such as the manual effort required for document conversion and the substantial computational resources \nneeded for text processing.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='This research significantly contributes to facilitating access and comprehension of educational \nlegal documents and opens opportunities for further development with more advanced conversion techniques and AI models.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Keywords: Question Answering; LangChain; BERTScore; ROUGE Score; Legal Documents; Education \n1. PENDAHULUAN  \nDalam perkembangan teknologi informasi yang pesat selama beberapa tahun terakhir, kemudahan dalam \nmengakses informasi telah menjadi salah satu pencapaian yang signifikan.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Kecerdasan buatan (AI) telah muncul \nsebagai alat yang potensial dalam menghadirkan solusi inovatif di berbagai sektor kehidupan manusia [1].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Tantangan utama yang dihadapi dalam penelitian ini adalah kompleksitas dalam mengakses dan memahami \ndokumen legal di bidang pendidikan.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='Dokumen tersebut seringkali sangat teknis dan padat dengan terminologi \nhukum, yang membuatnya sulit dipahami oleh orang awam.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 0}, page_content='
'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Penelitian yang dilakukan oleh Gobinda G. Chowdhury, \ndkk juga mendalami terkait topik dari nlp, Para peneliti Natural Language Processing (NLP) berupaya \nmengumpulkan pengetahuan tentang bagaimana manusia memahami dan menggunakan bahasa sehingga alat dan \nteknik yang sesuai dapat dikembangkan untuk membuat sistem komputer memahami dan memanipulasi bahasa \nalami untuk melaksanakan tugas yang diinginkan.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Penelitian ini juga memberikan dasar dasar dalam nlp terletak \ndi sejumlah disiplin ilmu, seperti ilmu komputer dan informasi, linguistik, matematika, teknik listrik dan \nelektronik, kecerdasan buatan dan robotika, psikologi, dll [15].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Selanjutnya pengujian pada penilitian ini akan \nmenggunakan bert score, penilitian yang dilakukan oleh Jacob Devlin, dkk melakukan pendekatan berbasis fine-\ntuning dengan mengusulkan BERT: Bidirectional Encoder Representations from Transformers.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Menurutnya \nTerdapat dua strategi yang ada untuk menerapkan representasi bahasa yang telah dilatih sebelumnya ke tugas-\ntugas lanjutan (downstream tasks): berbasis fitur dan fine-tuning [16].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Penelitian terbaru telah menunjukkan peningkatan signifikan dalam banyak tugas NLP dan tolok ukur \ndengan melakukan pra-pelatihan pada korpus teks yang besar diikuti dengan fine-tuning pada tugas tertentu.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Di \nsini, kami menunjukkan bahwa meningkatkan skala model bahasa secara signifikan meningkatkan kinerja few-\nshot yang tidak bergantung tugas, terkadang bahkan mencapai daya saing dengan pendekatan fine-tuning yang \nsebelumnya menjadi yang terbaik.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Secara khusus, kami melatih GPT-3, sebuah model bahasa autoregresif \ndengan 175 miliar parameter, 10 kali lebih besar dari model bahasa non-sparse sebelumnya, dan menguji \nkinerjanya dalam pengaturan few-shot [17].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Penelitian yang dilakukan oleh Zeynep Akkalyoncu Yilmaz, dkk \nmelakukan Demonstrasi yang berfokus pada tantangan teknis dalam integrasi kemampuan NLP dan IR, serta \nrasional desain di balik pendekatan kami untuk integrasi yang erat antara Python (untuk mendukung jaringan \nsaraf) dan Java Virtual Machine (untuk mendukung pengambilan dokumen menggunakan pustaka pencarian \nopen-source Lucene) [18].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Dalam memprediksi jawaban terbaik penelitian Wataru Sakata, dkk pada \npenilitiannya juga memanfaatkan bert score [19].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Dan diperlukan pemahaman terkait pemeringkatan dalam bert \nyang dilakukan dalam penelitian oleh Yifan Qiao, dkk [20].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='2. METODOLOGI PENELITIAN \nProses yang diikuti dalam penelitian ini untuk merancang dan mengembangkan questions answering berbasis \nweb dengan sumber konteks dokumen hukum di bidang pendidikan disajikan pada Gambar 1 berikut. Gambar 1.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Diagram Alur Penelitian'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 2}, page_content='Journal of Computer System and Informatics (JoSYC)  \nISSN 2714-8912 (media online), ISSN 2714-7150 (media cetak) \nVolume 9, No. 9, Month 2022, Page 999−999 \nhttps://ejurnal.seminar-id.com/index.php/josyc \nDOI 10.47065/josyc.v9i9.9999 \nCopyright © 2024 Author, Page 295  \nThis Journal is licensed under a Creative Commons Attribution 4.0 International License \nDari diagram alur penelitian yang ditampilkan pada Gambar 1, tahapan awal mencakup pengumpulan \ndata serta perancangan sistem/metode.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page':
'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='19–24, 2020. [19] W. Sakata, R. Tanaka, T. Shibata, and S. Kurohashi, “FAQ retrieval using query-question similarity and \nBERT-based query-answer relevance,” SIGIR 2019 - Proc.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='42nd Int. ACM SIGIR Conf. Res. Dev. Inf. Retr., \npp. 1113–1116, 2019, doi: 10.1145/3331184.3331326. [20] Y.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Qiao, C. Xiong, Z. Liu, and Z. Liu, “Understanding the Behaviors of BERT in Ranking,” 2019, \n[Online].'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Available: http://arxiv.org/abs/1904.07531. [21] T. Zhang, V. Kishore, F. Wu, K. Q. Weinberger, and Y. Artzi, “Bertscore: Evaluating Text Generation \nWith Bert,” 8th Int.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Conf. Learn. Represent. ICLR 2020, pp. 1–43, 2020. [22] J. Risch, T. Möller, J. Gutsch, and M. Pietsch, “Semantic Answer Similarity for Evaluating Question \nAnswering Models,” Proc.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='3rd Work. Mach. Read. Quest. Answering, MRQA 2021, pp. 149–157, 2021, \ndoi: 10.18653/v1/2021.mrqa-1.15.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='[23] A. Chen, G. Stanovsky, S. Singh, and M. Gardner, “Evaluating question answering evaluation,” \nMRQA@EMNLP 2019 - Proc.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='2nd Work. Mach. Read. Quest. Answering, pp. 119–124, 2019, doi: \n10.18653/v1/d19-5817. [24] M. Barbella and G.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Tortora, “Rouge Metric Evaluation for Text Summarization Techniques,” SSRN \nElectron. J., 2022, doi: 10.2139/ssrn.4120317.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='[25] G. Tsuchiya, “Postmortem Angiographic Studies on the Intercoronary Arterial Anastomoses.: Report I.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Studies on Intercoronary Arterial Anastomoses in Adult Human Hearts and the Influence on the \nAnastomoses of Strictures of the Coronary Arteries.,” Jpn.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Circ. J., vol. 34, no. 12, pp. 1213–1220, 1971, \ndoi: 10.1253/jcj.34.1213. [26] W. Tay, A. Joshi, X.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Zhang, S. Karimi, and S. Wan, “Red-faced ROUGE: Examining the Suitability of \nROUGE for Opinion Summary Evaluation,” Proc.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='17th Annu. Work. Australas. Lang. Technol. Assoc., pp. 52–60, 2019, [Online]. Available: https://www.aclweb.org/anthology/U19-1008.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='[27] Muchammad Catur Rizky, Rohman Hakim, Miftakhul Anam, Moch Nur Alim, and Wahyu Suhartatik, \n“Implementasi Undang-Undang Nomor 14 Tahun 2005 Tentang Guru dan Dosen terhadap Kesejahteraan \nDosen Profesional di Universitas Sunan Giri Surabaya,” J.'),
#  Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 11}, page_content='Kolaboratif Sains, vol. 5, no. 8, pp. 561–569, \n2022, doi: 10.56338/jks.v5i8.2734.')]

# %%
ASTRA_DB_API_ENDPOINT = os.getenv("ASTRA_DB_API_ENDPOINT")
ASTRA_DB_APPLICATION_TOKEN = os.getenv("ASTRA_DB_APPLICATION_TOKEN")

sparse_retriever = BM25Retriever.from_documents(chunks)
sparse_retriever.k = 5
embeddings = OpenAIEmbeddings(api_key = open_ai_api_key, model="text-embedding-3-small")

vectorstore = AstraDBVectorStore(
    embedding= embeddings,
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    collection_name="ScholarSyncV1",
    namespace=None
)

dense_retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

hybrid_retriever = EnsembleRetriever(
    retrievers=[sparse_retriever, dense_retriever],
    weights=[0.5, 0.5]
)

# %%
model_reranker = HuggingFaceCrossEncoder(model_name="cross-encoder/ms-marco-MiniLM-L-6-v2")

# Wrapper Reranker
compressor = CrossEncoderReranker(model=model_reranker, top_n=3) # Hanya ambil TOP 3 terbaik setelah reranking

# Final Retriever: Hybrid -> Reranking
final_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=hybrid_retriever
)
# Out:
# d:\anaconda3\envs\ScholarSync_env\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Farhan Kamil\.cache\huggingface\hub\models--cross-encoder--ms-marco-MiniLM-L-6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %%
llm = BytePlusLLM(api_key=api_key, endpoint_id=endpoint_id)

# %%
qa_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a scholarly assistant. Answer the question based ONLY on the context provided. If you don't know, say so.\n\nContext:\n{context}"),
    ("user", "{input}")
])

# %%
question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)
rag_chain = create_retrieval_chain(final_retriever, question_answer_chain)

# %%
response = rag_chain.invoke({
    "input" : "bagaimana membuat chatbot dengan langchain"
})
response
# Out:
# {'input': 'bagaimana membuat chatbot dengan langchain',
#  'context': [Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Penilitian ini juga melakukan \npendekatan seperti yang dilakukan oleh Arjun Pesaru, dkk yakni Pendekatan memanfaatkan kekuatan LangChain \ndan Model Large Language Models (LLM) untuk membuat chatbot yang dapat menjawab pertanyaan tentang \nberkas PDF [8].'),
#   Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Selanjutnya penelitian Tiago Lubiana, dkk bertujuan \nuntuk memberikan panduan praktis dan berguna bagi para peneliti dan profesional dalam bidang biologi \nkomputasi tentang bagaimana memanfaatkan ChatGPT secara optimal [7].'),
#   Document(metadata={'producer': 'Microsoft® Word 2010', 'creator': 'Microsoft® Word 2010', 'creationdate': '2024-12-11T15:20:15+07:00', 'source': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'file_path': '../data/Aplikasi Web Question Answering Menggunakan Langchain OpenAI.pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-11T15:20:15+07:00', 'trapped': '', 'modDate': "D:20241211152015+07'00'", 'creationDate': "D:20241211152015+07'00'", 'page': 1}, page_content='Penelitian yang dilakukan oleh Gobinda G. Chowdhury, \ndkk juga mendalami terkait topik dari nlp, Para peneliti Natural Language Processing (NLP) berupaya \nmengumpulkan pengetahuan tentang bagaimana manusia memahami dan menggunakan bahasa sehingga alat dan \nteknik yang sesuai dapat dikembangkan untuk membuat sistem komputer memahami dan memanipulasi bahasa \nalami untuk melaksanakan tugas yang diinginkan.')],
#  'answer': 'Berdasarkan konteks yang disediakan, informasi spesifik tentang cara membuat chatbot dengan LangChain tidak dijelaskan. Konteks hanya menyebutkan bahwa penelitian Arjun Pesaru, dkk menggunakan pendekatan dengan memanfaatkan kekuatan LangChain dan LLM untuk membuat chatbot yang dapat menjawab pertanyaan tentang berkas PDF.'}

# %%
response = rag_chain.invoke({
    "input" : "Bagaimana chatbot bisa menjawab pertanyaan tentang berkas pdf?"
})
response['answer']
# Out:
# 'Berdasarkan konteks yang disediakan, chatbot dapat menjawab pertanyaan tentang berkas PDF dengan memanfaatkan kekuatan framework LangChain dan Model Large Language Models (LLM).'

# %%
vectorstore.
